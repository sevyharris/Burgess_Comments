# %%
import os 
import re
import matplotlib.pyplot as plt
import rmgpy.chemkin
import numpy as np
import cantera as ct
import pandas as pd
# %matplotlib inline

# %%
def load_chemkin_file(path): 
    """ 
    Load Chemkin file and extract the reactions and species.
    Path should be the path to the species folder.
    """
    
    full_path = os.path.join(path,'chemkin')
    chemkin_path = os.path.join(full_path,'copies', 'copy_chem_annotated.inp')
   # chemkin_path = os.path.join(full_path,'chem_annotated.inp')
    dictionary_path = os.path.join(full_path,'species_dictionary.txt')
    transport_path = os.path.join(full_path,'tran.dat')

    species_list, reaction_list = rmgpy.chemkin.load_chemkin_file(chemkin_path, dictionary_path=dictionary_path, transport_path=transport_path)

    return species_list, reaction_list

# %%
############# load the chemkin file and the cantera dataframe ################

#file = 'sensitivites_copy_chem_annotated.cti.csv'
species_list, reaction_list = load_chemkin_file('/work/westgroup/nora/Code/projects/halogens/refrigerants/singles/Burgess_Comments/methane_with_added_2_BTP/cantera/Nora/2_BTP')
df = pd.read_csv('./2_BTP_sensitivities.csv')

# %% [markdown]
# ## Analysis of Reaction Families

# %%
i=0 # counter, for assertion error later 
reaction_family_data = []  #to save reaction family data 



for index,row in df.head(n).iterrows(): #Only iterate over the first n rows
    
        
    ct_index, sensitivity, ct_equation, ct_products, ct_reactants = row['k_s'], row['sensitivity'], row['cantera equation'], eval(row['cantera products']), eval(row['cantera reactants'])
   
    #list of all products in each reaction 
    list_of_products = [(k+',')*int(v) for k,v in ct_products.items()]   #use ',' as a marker for distinction between different species
    products = set(list(filter(None, (''.join(list_of_products)).split(',')))) #now make all the products into a list. If two of the same species are listed as reactants, they should appear as two entries

    #list of all reactants in each reaction 
    list_of_reactants = [(k+',')*int(v) for k,v in ct_reactants.items()]   #use ',' as a marker for distinction between different species
    reactants= set(list(filter(None, (''.join(list_of_reactants)).split(',')))) #now make all the products into a list. If two of the same species are listed as reactants, they should appear as two entries

    
    #iterate through rmg reactions and find the match to the cantera reaction
    for rmg_rxn in reaction_list: 
            rmg_reactants = set([str(i.to_chemkin()) for i in rmg_rxn.reactants])
            rmg_products = set([str(i.to_chemkin()) for i in rmg_rxn.products])
            
            if (reactants==rmg_reactants) and (products==rmg_products) and ('M' in ct_equation) and ('M' in str(rmg_rxn)):
                reaction_family_data.append(rmg_rxn.family)
                #print(ct_index,'appended')
                i += 1 #for assertion error
                break
            if (reactants==rmg_reactants) and (products==rmg_products) and ('M' not in ct_equation) and ('M' not in str(rmg_rxn)):
                try: 
                    reaction_family_data.append(rmg_rxn.family)
                    #print(ct_index,'appended')
                    i += 1 #for assertion error
                    break
                except AttributeError:
                    reaction_family_data.append('PDepReaction')
                    #print(ct_index, 'appended')
                    i += 1 #for assertion error
                    break
            if (reactants==rmg_reactants) and (products==rmg_products)and ('M' in ct_equation) and ('M' not in str(rmg_rxn)) :
                reaction_family_data.append('PDepReaction')
                i += 1 #for assertion error
                break

print(i,n)
assert i==n, "Not all equations in Cantera sensitivity analysis were matched!"




############ organize data into a second dataframe
data = {
    'cantera equations': df['cantera equation'][:n],
    'sensitivities': df['sensitivity'][:n],
    'reaction family': reaction_family_data,
}


df2 = pd.DataFrame(data)

df2

############## STYLE IT UP
halogen_families = [
    'Cl_Abstraction',
    'F_Abstraction',
    'Br_Abstraction',
    'XY_Addition_MultipleBond',
    '1,2_XY_interchange',
    'halocarbene_recombination',
    'halocarbene_recombination_double',
    'halocarbene_CO_dimerization',
    'XY_elimination_hydroxyl',
    'intra_halogen_migration',
    'Disproportionation-Y',
]

target_family = ['halocarbene_recombination']

def highlight_rows(x):
    if x['reaction family'] in target_family:
        return['background-color: pink']*3
    if x['reaction family'] in halogen_families:
        return['background-color: yellow']*3
    else:
        return['background-color: white']*3
display(df2.style.apply(highlight_rows, axis = 1))
# Out:
# 1474 1474
# <style  type="text/css" >
# #T_cdddc470_6773_11ed_902c_fffe7cb55a6brow0_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow0_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow0_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow1_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow1_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow1_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow2_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow2_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow2_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow3_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow3_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow3_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow4_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow4_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow4_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow5_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow5_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow5_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow6_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow6_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow6_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow7_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow7_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow7_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow8_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow8_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow8_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow9_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow9_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow9_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow10_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow10_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow10_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow11_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow11_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow11_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow12_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow12_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow12_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow13_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow13_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow13_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow14_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow14_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow14_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow15_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow15_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow15_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow16_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow16_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow16_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow17_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow17_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow17_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow18_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow18_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow18_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow19_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow19_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow19_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow20_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow20_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow20_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow21_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow21_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow21_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow22_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow22_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow22_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow23_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow23_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow23_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow24_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow24_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow24_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow25_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow25_col1,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow25_col2,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow26_col0,#T_cdddc470_6773_11ed_902c_fffe7cb55a6brow26_col1,#T_cdddc470_6773_11ed_902c_fff ...
