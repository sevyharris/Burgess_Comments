# %%
import matplotlib.pylab as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Plotting

# %% [markdown]
# From web data digitilizer

# %%
#FROM web data digitalizer

#experimental data at 298 K 
exper_fracs = [0, 0.5/100, 0.9984326018808776/100, 1.4968652037617554/100, 1.9984326018808776/100]
exper_speeds = [35.97260273972603, 24.575342465753423, 16.246575342465754, 9.890410958904113, 6]

ugly = [0, 38.986301369863014,
0.12068965517241381, 36.08219178082192,
0.22727272727272718, 33.61643835616439,
0.32131661442006265, 31.369863013698634,
0.40282131661442, 29.34246575342466,
0.49686520376175536, 27.095890410958905,
0.5721003134796236, 25.616438356164387,
0.6818181818181817, 23.424657534246577,
0.7821316614420062, 21.5068493150685,
0.891849529780564, 19.47945205479452,
0.9984326018808776, 17.561643835616444,
1.1520376175548586, 15.150684931506852,
1.3087774294670846, 12.958904109589042,
1.4811912225705324, 10.93150684931507,
1.6567398119122256, 9.287671232876711,
1.8197492163009403, 8.027397260273979,
1.9984326018808776, 6.986301369863014,
2.1959247648902815, 6,
2.384012539184953, 5.397260273972606,
2.606583072100313, 4.794520547945204,
2.813479623824451, 4.410958904109592,
2.998432601880878, 3.972602739726028]

NIST_fracs = []
NIST_speeds = []

for id, val in enumerate(ugly):
    if id % 2 == 0:
        NIST_fracs.append(val/100)
    else: 
        NIST_speeds.append(val)

# %% [markdown]
# edited RMG Data

# %%
fig = plt.figure()

# NIST with Ms
M_BTP_vol_fracs = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
M_BTP_spds = np.array([0.40875258641290235,0.3182666324650983,0.2440402557602658,0.18139435112886126,0.1303768658455397,0.09263736887130462,0.0711125967129613,0.05744824265032554,0.04768965204998258,0.04058391866598579])
M_BTP_speeds = M_BTP_spds*100

#RMG with BROH in core (136 species)
vol_fracs_BROH = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
RMG_BROH_spds = np.array([0.36851221059170974,0.2878430240094766,0.18200878449613728,0.06219629394921892,0.04622096263001605,0.038864010371782644,0.03398605582038517,0.030206883726294074,0.02708480325828628,0.0244917393480474])
RMG_BROH_speeds = RMG_BROH_spds*100

#RMG with BROH in core (148 species)
vol_fracs_BROH_148 = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
RMG_BROH_spds_148 = np.array([0.36831504416476546,0.30163978217619686,0.25432946947045454,0.2062565529838945,0.15978155063129598,0.11825315989400599,0.08754163532914323,0.06781429217230077,0.053701126472168785,0.04368254711272286])

#RMG with BROH in core (150 species)
RMG_BROH_spds_150=np.array([0.36831504416476585,0.3016391418745802,0.25432873457132055,0.2062614894833247,0.15977967747684407,0.11825293933512782,0.08754646801165031,0.0678243192801583,0.053715176011001745,0.04369751670049656])


#RMG with BROH in core (182 species)
RMG_BROH_spds_182=np.array([0.36831504413112015,0.30185346214452147,0.25458736961911554,0.20679001195078783,0.15998785652487788,0.11863641572305074,0.08783919096158373,0.06816649439932086,0.054184280599402716,0.04401072179371192])

#RMG with BROH in core (204 species)
RMG_BROH_spds_204=np.array([0.368315044175012,0.3017671008238044,0.25380733121765137,0.20534112958516446,0.15912066586519652,0.11855354592652835,0.08757491901487018,0.06804028876795941,0.054099501348186745,0.0439099170700266])

#RMG original (without BROH in core)
rmg_original = np.array([0.36836118323651834,0.31050762830488216,0.2695128172909165,0.22789946613022974,0.18438916925493348,0.1429087785778958,0.10739053748308872,0.08418438770424427,0.0686499399546852,0.05698769585957772])

#RMG with BROH in core (204 species) with reaction 777 taken out
RMG_BROH_spds_777=np.array([0.36831504417501215,0.2977999344429407,0.24792265016780599,0.1994948047078138,0.15493991388425216,0.1166535353593989,0.08807068658514465,0.07007730520543214,0.05738460403382252,0.04782972825100913])




#plotting
ax1 = fig.add_subplot(111)  

ax1.plot(M_BTP_vol_fracs, M_BTP_speeds, '-', c='g', label='NIST model' )
ax1.plot(exper_fracs, exper_speeds, '-', c='b', label='experimental, paper' )
ax1.plot(NIST_fracs, NIST_speeds, '-', c='r', label='NIST, paper' )
#ax1.plot(vol_fracs_BROH, RMG_BROH_speeds, '-', c='m', label='RMG w/ BROH (136)' )
#ax1.plot(vol_fracs_BROH_148,RMG_BROH_spds_148*100, '-', c='orange', label='RMG w/ BROH (148)' )
# ax1.plot(vol_fracs_BROH_148, rmg_original * 100, '-', c='violet', label='RMG original' )
# ax1.plot(vol_fracs_BROH_148, RMG_BROH_spds_150 * 100, '-', c='yellow', label='RMG w/ BROH (150)' )
# ax1.plot(vol_fracs_BROH_148, RMG_BROH_spds_182 * 100, '-', c='yellow', label='RMG w/ BROH (182)' )
ax1.plot(vol_fracs_BROH_148, RMG_BROH_spds_204 * 100, '-', c='yellow', label='RMG w/ BROH (204)' )
#ax1.plot(vol_fracs_BROH_148, RMG_BROH_spds_777 * 100, '-', c='m', label='RMG w/ BROH 777' )

 


plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Different Model Sizes (120-140)')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))
