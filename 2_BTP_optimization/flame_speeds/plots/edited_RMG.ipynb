# %%
import matplotlib.pylab as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Plotting

# %% [markdown]
# From web data digitilizer

# %%
#FROM web data digitalizer

#experimental data at 298 K 
exper_fracs = [0, 0.5/100, 0.9984326018808776/100, 1.4968652037617554/100, 1.9984326018808776/100]
exper_speeds = [35.97260273972603, 24.575342465753423, 16.246575342465754, 9.890410958904113, 6]

ugly = [0, 38.986301369863014,
0.12068965517241381, 36.08219178082192,
0.22727272727272718, 33.61643835616439,
0.32131661442006265, 31.369863013698634,
0.40282131661442, 29.34246575342466,
0.49686520376175536, 27.095890410958905,
0.5721003134796236, 25.616438356164387,
0.6818181818181817, 23.424657534246577,
0.7821316614420062, 21.5068493150685,
0.891849529780564, 19.47945205479452,
0.9984326018808776, 17.561643835616444,
1.1520376175548586, 15.150684931506852,
1.3087774294670846, 12.958904109589042,
1.4811912225705324, 10.93150684931507,
1.6567398119122256, 9.287671232876711,
1.8197492163009403, 8.027397260273979,
1.9984326018808776, 6.986301369863014,
2.1959247648902815, 6,
2.384012539184953, 5.397260273972606,
2.606583072100313, 4.794520547945204,
2.813479623824451, 4.410958904109592,
2.998432601880878, 3.972602739726028]

NIST_fracs = []
NIST_speeds = []

for id, val in enumerate(ugly):
    if id % 2 == 0:
        NIST_fracs.append(val/100)
    else: 
        NIST_speeds.append(val)

# %% [markdown]
# edited RMG Data

# %%
vol_fracs = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]

#edited RMG data
rxn_1 = np.array([0.35142625279734735,0.2963615777459447,0.255303263182583,0.21515880460673933,0.1732482491720625,0.13446135152462152,0.10091802033856816,0.07980360249580529,0.06527490947679244,0.05387029316984352])
rxn_13 = np.array([0.3671575150037971,0.3092404822086529,0.26826481784593464,0.22682683061888054,0.18360729388298005,0.1425033564020256,0.10726272998300516,0.08415346643990193,0.06864148910970817,0.05698501933002047])
rxn_30 = np.array([0.36780981702773474,0.3100613913726076,0.26918128703683347,0.22768147295929522,0.18426285269017553,0.14283529889404917,0.10734138151615545,0.0841473336515654,0.0686205201552733,0.05696281546269539])
rxn_33 = np.array([0.37757948181188083,0.3207405758402789,0.2796526630479889,0.2378729449853478,0.19358544956698062,0.1504997900421967,0.11300955938082735,0.08728954758948067,0.07095430409351808,0.058598533255079105])
rxn_357 = np.array([0.3937845881597761,0.33349118313632997,0.2878006206789745,0.24192722742563957,0.19445931591876808,0.15046869374932645,0.11260311866818076,0.08707643511728372,0.07086780090743688,0.05864246153066736])
rxn_374 = np.array([0.36318213432425633,0.30195517654571735,0.25903492414734997,0.2144864042423417,0.16939339654920219,0.12845811544135996,0.09598573627743583,0.07626407806802205,0.06238880416582256,0.052527911997999194])
rxn_38 = np.array([0.3602909823896263,0.30687333417097734,0.26735318235389355,0.22606671133354778,0.18369859255603302,0.14233620280827736,0.10684482485563676,0.08395301173348381,0.0685036722832204,0.056797201391043134])
rxn_58 = np.array([0.3681031287659626,0.31171940695626144,0.27146298813144504,0.23150565109783736,0.18908904493721182,0.14642272187149938,0.1103221420206402,0.08561768370870733,0.06952004537532365,0.0575896211825638])
rxn_685 = np.array([0.3683611832365184,0.3137507599703961,0.2726553703839355,0.23080759552416547,0.18724081887604602,0.14437767921337538,0.10836284628180883,0.08473992524593243,0.0689743115441241,0.05715037656890825])
rxn_746_NC = np.array([0.36836118323651834,0.31050762830488216,0.2695128172909165,0.22789946613022974,0.18438916925493348,0.1429087785778958,0.10739053748308872,0.08418438770424427,0.0686499399546852,0.05698769585957772])
rxn_91 = np.array([0.360816483534227,0.3013760901053498,0.261566214385099,0.22055134220108227,0.178551798249997,0.13912168065278183,0.10511363486318151,0.08291732723902297,0.06792645958252909,0.05653149960824355])

# %%
fig = plt.figure()

# NIST with Ms
M_BTP_vol_fracs = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
M_BTP_spds = np.array([0.40875258641290235,0.3182666324650983,0.2440402557602658,0.18139435112886126,0.1303768658455397,0.09263736887130462,0.0711125967129613,0.05744824265032554,0.04768965204998258,0.04058391866598579])
M_BTP_speeds = M_BTP_spds*100




#plotting
ax1 = fig.add_subplot(111)  

ax1.plot(M_BTP_vol_fracs, M_BTP_speeds, '-', c='g', label='NIST model, M' )
ax1.plot(exper_fracs, exper_speeds, '-', c='b', label='experimental, paper' )
ax1.plot(NIST_fracs, NIST_speeds, '-', c='r', label='NIST, paper' )

#RMG's 2-BTP (same as "changing" 746 because there was no change in kinetics)
ax1.plot(vol_fracs, rxn_746_NC * 100, '-', c='m', label='RMG' )

plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Different Model Sizes (120-140)')
ax1.legend(bbox_to_anchor=(0.5, 0., 0.8, 1))

# %%
#wrong data 
RMG_with_840_not_pdep_vf= [0.0,0.0034246488829682868,0.01355928812903828,0.02675578683525816,0.029999926235735837]
RMG_with_840_not_pdep = np.array([0.36107327254607946,0.250555167496699,0.10745362172398058,0.05542823563046761,0.048609489154778474])

# %%
fig = plt.figure()

# NIST with Ms
M_BTP_vol_fracs = [0.0,0.0034246488829682868,0.006825921381900819,0.01020405603073009,0.01355928812903828,0.016891849796691408,0.02020197002736977,0.023489874741020596,0.02675578683525816,0.029999926235735837]
M_BTP_spds = np.array([0.40875258641290235,0.3182666324650983,0.2440402557602658,0.18139435112886126,0.1303768658455397,0.09263736887130462,0.0711125967129613,0.05744824265032554,0.04768965204998258,0.04058391866598579])
M_BTP_speeds = M_BTP_spds*100


#plotting
ax1 = fig.add_subplot(111)  

ax1.plot(M_BTP_vol_fracs, M_BTP_speeds, '-', c='g', label='NIST model, M' )
ax1.plot(exper_fracs, exper_speeds, '-', c='b', label='experimental, paper' )
ax1.plot(NIST_fracs, NIST_speeds, '-', c='r', label='NIST, paper' )

#edited RMG data
# ax1.plot(vol_fracs, rxn_1 * 100, '-', label='1' )
# ax1.plot(vol_fracs, rxn_13 * 100, '-', label='13' )
# ax1.plot(vol_fracs, rxn_30 * 100, '-', c='yellow',label='30' )
# ax1.plot(vol_fracs, rxn_33 * 100, '-', label='33' )
# ax1.plot(vol_fracs, rxn_357 * 100, '-', label='357' )
#ax1.plot(vol_fracs, rxn_374 * 100, '-', label='374' )
#ax1.plot(vol_fracs, rxn_38 * 100, '-', label='38' )
#ax1.plot(vol_fracs, rxn_58 * 100, '-', label='58' )
ax1.plot(vol_fracs, rxn_685 * 100, '-', label='685' )
ax1.plot(vol_fracs, rxn_746_NC * 100, '-', label='746_NC' )
#ax1.plot(vol_fracs, rxn_91 * 100, '-', label='91' )

#better fitting but wrong data
ax1.plot(RMG_with_840_not_pdep_vf, RMG_with_840_not_pdep*100, '-', label='RMG with 840 replaced, not pdep' ) #replaced with NIST reaction('HF <=> H + F', [3.120000e+13, 0.0, 99320.0])

plt.xlabel('2-BTP volume fraction')
plt.ylabel('Su (cm/s)')
plt.title('Flame Speeds of Different Model Sizes (120-140)')
ax1.legend(bbox_to_anchor=(1, 0., 0.8, 1))
